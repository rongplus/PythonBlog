# %%
import requests
import os
import datetime
import json
import random
import time



def getCount():
    url = "http://192.168.4.227:9200/bell/devices/_search"

    payload = ""
    headers = {
        'cache-control': "no-cache",
        'Postman-Token': "3d66f7bf-825c-4e6c-819b-2b5ad71a4b9e"
        }

    response = requests.request("GET", url, data=payload, headers=headers)

    all_data_obj = response.json()
    return all_data_obj['hits']['total']

def insertOne(lat,lng,total,iddd, num):    
    url = "http://192.168.4.227:9200/bell/devices/" + str(total)
    data_obj = {}
    data_obj['id'] = iddd
    data_obj['time'] = datetime.datetime.now().strftime("%Y-%m-%d")
    data_obj['strong'] = num
    pt ={}
    pt['lat'] = lat
    pt['lon'] = lng

    data_obj['location'] = pt

    headers = {
        'Content-Type': "application/json",
        'cache-control': "no-cache",
        'Postman-Token': "5903c58a-624c-46cb-98a4-fe6f90746b04"
        }

    #response = requests.request("POST", url, data=json.dumps(data_obj), headers=headers)
    response = requests.post(url, headers=headers, params='', data=json.dumps(data_obj))
    print(response.text)
    
pt1X = 43.390987
pt1Y = -80.807945

pt2X = 43.753992
pt2Y = -79.425480

x = (pt2X - pt1X)/100
y = (pt2Y - pt1Y)/100

for i in range(100):
    print(getCount())
    time.sleep(2)
    insertOne(pt1X+ x*i,pt1Y + y*i, getCount()+1,"iddd", random.randint(0,30))
    time.sleep(2)
# Out:
# 24
# {"_index":"bell","_type":"devices","_id":"25","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":98,"_primary_term":5}
# 25
# {"_index":"bell","_type":"devices","_id":"26","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":99,"_primary_term":5}
# 26
# {"_index":"bell","_type":"devices","_id":"27","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":141,"_primary_term":5}
# 27
# {"_index":"bell","_type":"devices","_id":"28","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":5,"_primary_term":5}
# 28
# {"_index":"bell","_type":"devices","_id":"29","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":100,"_primary_term":5}
# 29
# {"_index":"bell","_type":"devices","_id":"30","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":78,"_primary_term":5}
# 30
# {"_index":"bell","_type":"devices","_id":"31","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":5,"_primary_term":5}
# 31
# {"_index":"bell","_type":"devices","_id":"32","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":79,"_primary_term":5}
# 32
# {"_index":"bell","_type":"devices","_id":"33","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":80,"_primary_term":5}
# 33
# {"_index":"bell","_type":"devices","_id":"34","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":81,"_primary_term":5}
# 34
# {"_index":"bell","_type":"devices","_id":"35","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":142,"_primary_term":5}
# 35
# {"_index":"bell","_type":"devices","_id":"36","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":143,"_primary_term":5}
# 36
# {"_index":"bell","_type":"devices","_id":"37","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":6,"_primary_term":5}
# 37
# {"_index":"bell","_type":"devices","_id":"38","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":144,"_primary_term":5}
# 38
# {"_index":"bell","_type":"devices","_id":"39","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":6,"_primary_term":5}
# 39
# {"_index":"bell","_type":"devices","_id":"40","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":101,"_primary_term":5}
# 40
# {"_index":"bell","_type":"devices","_id":"41","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":102,"_primary_term":5}
# 41
# {"_index":"bell","_type":"devices","_id":"42","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":82,"_primary_term":5}
# 42
# {"_index":"bell","_type":"devices","_id":"43","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":145,"_primary_term":5}
# 43
# {"_index":"bell","_type":"devices","_id":"44","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":103,"_primary_term":5}
# 44
# {"_index":"bell","_type":"devices","_id":"45","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":7,"_primary_term":5}
# 45
# {"_index":"bell","_type":"devices","_id":"46","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":7,"_primary_term":5}
# 46
# {"_index":"bell","_type":"devices","_id":"47","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":8,"_primary_term":5}
# 47
# {"_index":"bell","_type":"devices","_id":"48","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":104,"_primary_term":5}
# 48
# {"_index":"bell","_type":"devices","_id":"49","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":8,"_primary_term":5}
# 49
# {"_index":"bell","_type":"devices","_id":"50","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":9,"_primary_term":5}
# 50
# {"_index":"bell","_type":"devices","_id":"51","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":146,"_primary_term":5}
# 51
# {"_index":"bell","_type":"devices","_id":"52","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":105,"_primary_term":5}
# 52
# {"_index":"bell","_type":"devices","_id":"53","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":10,"_primary_term":5}
# 53
# {"_index":"bell","_type":"devices","_id":"54","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":147,"_primary_term":5}
# 54
# {"_index":"bell","_type":"devices","_id":"55","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":148,"_primary_term":5}
# 55
# {"_index":"bell","_type":"devices","_id":"56","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":11,"_primary_term":5}
# 56
# {"_index":"bell","_type":"devices","_id":"57","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":149,"_primary_term":5}
# 57
# {"_index":"bell","_type":"devices","_id":"58","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":12,"_primary_term":5}
# 58
# {"_index":"bell","_type":"devices","_id":"59","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":83,"_primary_term":5}
# 59
# {"_index":"bell","_type":"devices","_id":"60","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":106,"_primary_term":5}
# 60
# {"_index":"bell","_type":"devices","_id":"61","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":13,"_primary_term":5}
# 61
# {"_index":"bell","_type":"devices","_id":"62","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":84,"_primary_term":5}
# 62
# {"_index":"bell","_type":"devices","_id":"63","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":14,"_primary_term":5}
# 63
# {"_index":"bell","_type":"devices","_id":"64","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":15,"_primary_term":5}
# 64
# {"_index":"bell","_type":"devices","_id":"65","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":85,"_primary_term":5}
# 65
# {"_index":"bell","_type":"devices","_id":"66","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":9,"_primary_term":5}
# 66
# {"_index":"bell","_type":"devices","_id":"67","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":10,"_primary_term":5}
# 67
# {"_index":"bell","_type":"devices","_id":"68","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":16,"_primary_term":5}
# 68
# {"_index":"bell","_type":"devices","_id":"69","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":17,"_primary_term":5}
# 69
# {"_index":"bell","_type":"devices","_id":"70","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":86,"_primary_term":5}
# 70
# {"_index":"bell","_type":"devices","_id":"71","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":11,"_primary_term":5}
# 71
# {"_index":"bell","_type":"devices","_id":"72","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":12,"_primary_term":5}
# 72
# {"_index":"bell","_type":"devices","_id":"73","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":107,"_primary_term":5}
# 73
# {"_index":"bell","_type":"devices","_id":"74","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":18,"_primary_term":5}
# 74
# {"_index":"bell","_type":"devices","_id":"75","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":19,"_primary_term":5}
# 75
# {"_index":"bell","_type":"devices","_id":"76","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":20,"_primary_term":5}
# 76
# {"_index":"bell","_type":"devices","_id":"77","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":13,"_primary_term":5}
# 77
# {"_index":"bell","_type":"devices","_id":"78","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":87,"_primary_term":5}
# 78
# {"_index":"bell","_type":"devices","_id":"79","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":108,"_primary_term":5}
# 79
# {"_index":"bell","_type":"devices","_id":"80","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":150,"_primary_term":5}
# 80
# {"_index":"bell","_type":"devices","_id":"81","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":14,"_primary_term":5}
# 81
# {"_index":"bell","_type":"devices","_id":"82","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":88,"_primary_term":5}
# 82
# {"_index":"bell","_type":"devices","_id":"83","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":21,"_primary_term":5}
# 83
# {"_index":"bell","_type":"devices","_id":"84","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":109,"_primary_term":5}
# 84
# {"_index":"bell","_type":"devices","_id":"85","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":151,"_primary_term":5}
# 85
# {"_index":"bell","_type":"devices","_id":"86","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":15,"_primary_term":5}
# 86
# {"_index":"bell","_type":"devices","_id":"87","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":89,"_primary_term":5}
# 87
# {"_index":"bell","_type":"devices","_id":"88","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":90,"_primary_term":5}
# 88
# {"_index":"bell","_type":"devices","_id":"89","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":110,"_primary_term":5}
# 89
# {"_index":"bell","_type":"devices","_id":"90","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":22,"_primary_term":5}
# 90
# {"_index":"bell","_type":"devices","_id":"91","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":23,"_primary_term":5}
# 91
# {"_index":"bell","_type":"devices","_id":"92","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":111,"_primary_term":5}
# 92
# {"_index":"bell","_type":"devices","_id":"93","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":152,"_primary_term":5}
# 93
# {"_index":"bell","_type":"devices","_id":"94","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":91,"_primary_term":5}
# 94
# {"_index":"bell","_type":"devices","_id":"95","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":16,"_primary_term":5}
# 95
# {"_index":"bell","_type":"devices","_id":"96","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":92,"_primary_term":5}
# 96
# {"_index":"bell","_type":"devices","_id":"97","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":17,"_primary_term":5}
# 97
# {"_index":"bell","_type":"devices","_id":"98","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":112,"_primary_term":5}
# 98
# {"_index":"bell","_type":"devices","_id":"99","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":113,"_primary_term":5}
# 99
# {"_index":"bell","_type":"devices","_id":"100","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":93,"_primary_term":5}
# 100
# {"_index":"bell","_type":"devices","_id":"101","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":94,"_primary_term":5}
# 101
# {"_index":"bell","_type":"devices","_id":"102","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":24,"_primary_term":5}
# 102
# {"_index":"bell","_type":"devices","_id":"103","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":95,"_primary_term":5}
# 103
# {"_index":"bell","_type":"devices","_id":"104","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":96,"_primary_term":5}
# 104
# {"_index":"bell","_type":"devices","_id":"105","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":114,"_primary_term":5}
# 105
# {"_index":"bell","_type":"devices","_id":"106","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":153,"_primary_term":5}
# 106
# {"_index":"bell","_type":"devices","_id":"107","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":18,"_primary_term":5}
# 107
# {"_index":"bell","_type":"devices","_id":"108","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":115,"_primary_term":5}
# 108
# {"_index":"bell","_type":"devices","_id":"109","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":154,"_primary_term":5}
# 109
# {"_index":"bell","_type":"devices","_id":"110","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":116,"_primary_term":5}
# 110
# {"_index":"bell","_type":"devices","_id":"111","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":19,"_primary_term":5}
# 111
# {"_index":"bell","_type":"devices","_id":"112","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":20,"_primary_term":5}
# 112
# {"_index":"bell","_type":"devices","_id":"113","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":97,"_primary_term":5}
# 113
# {"_index":"bell","_type":"devices","_id":"114","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":155,"_primary_term":5}
# 114
# {"_index":"bell","_type":"devices","_id":"115","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":21,"_primary_term":5}
# 115
# {"_index":"bell","_type":"devices","_id":"116","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":117,"_primary_term":5}
# 116
# {"_index":"bell","_type":"devices","_id":"117","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":98,"_primary_term":5}
# 117
# {"_index":"bell","_type":"devices","_id":"118","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":156,"_primary_term":5}
# 118
# {"_index":"bell","_type":"devices","_id":"119","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":118,"_primary_term":5}
# 119
# {"_index":"bell","_type":"devices","_id":"120","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":119,"_primary_term":5}
# 120
# {"_index":"bell","_type":"devices","_id":"121","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":22,"_primary_term":5}
# 121
# {"_index":"bell","_type":"devices","_id":"122","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":25,"_primary_term":5}
# 122
# {"_index":"bell","_type":"devices","_id":"123","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":120,"_primary_term":5}
# 123
# {"_index":"bell","_type":"devices","_id":"124","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":23,"_primary_term":5}
